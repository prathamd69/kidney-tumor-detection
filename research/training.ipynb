# %%
"""For first iteration let's just try to predict 1/0 for (tumor)/(normal-cyst-stone)
This will turn it into binary classification which can be easy to implement initially as
we have a large dataset and complex pipelines.
to maintain reproducibility we are going like this. """

# %%
import pandas as pd 
path = r"C:\Users\prath\OneDrive\Documents\GitHub\kidney-tumor-detection\data\raw\kidneyData.csv"
data = pd.read_csv(path)

# %%
columns_to_drop = ['Unnamed: 0', 'path', 'diag', 'Class']
data = data.drop(columns=columns_to_drop, errors='ignore')

# %%
data['finaltarget'] = data['target'].map({0: 0, 1: 0, 2: 0, 3: 1})

# %%
data['finaltarget'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
import tensorflow as tf

model = tf.keras.applications.ResNet50V2(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
    name="resnet50v2",
)
